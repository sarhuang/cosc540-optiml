# %%
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
apples = pd.read_csv('../data/apples_clean.csv')
stroke = pd.read_csv('../data/stroke_clean.csv')
accidents = pd.read_csv('../data/accident_clean.csv')
spotify = pd.read_csv('../data/spotify_clean.csv').drop(columns=['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name'])

# %%
apples_columns = ['Classifier', 'Accuracy', 'Precision', 'Recall', 'F1']
apples_results = pd.DataFrame(columns=apples_columns)
apples_rows = []

# %% [markdown]
# ## Apple Quality

# %%
y = apples['Quality'].to_numpy()
apples_x = apples[['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity']]
X = apples_x.to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### K-Nearest Neighbors

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'KNN',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

apples_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/apples/knn_cm.png')
plt.show()

# %% [markdown]
# #### Support Vector Machine

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'SVM',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

apples_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/apples/svm_cm.png')
plt.show()

# %% [markdown]
# #### Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'NB',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

apples_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/apples/naive_cm.png')
plt.show()

# %% [markdown]
# #### Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'RF',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

apples_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/apples/rf_cm.png')
plt.show()

# %% [markdown]
# #### Logistic Regression

# %%
logreg = LogisticRegression(random_state=42)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'LR',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

apples_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/apples/log_reg_cm.png')
plt.show()

# %% [markdown]
# #### Decision Tree

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'DT',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

apples_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/apples/d_tree_cm.png')
plt.show()

# %%
apples_results = pd.concat([apples_results, pd.DataFrame(apples_rows)], ignore_index=True)
print(apples_results)
# Out:
#   Classifier  Accuracy  Precision    Recall        F1
# 0        KNN  0.890152   0.899543  0.882090  0.890731
# 1        SVM  0.890152   0.898331  0.883582  0.890895
# 2         NB  0.745455   0.755352  0.737313  0.746224
# 3         RF  0.887121   0.891729  0.885075  0.888390
# 4         LR  0.750000   0.748538  0.764179  0.756278
# 5         DT  0.793939   0.794379  0.801493  0.797920
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/2912211423.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   apples_results = pd.concat([apples_results, pd.DataFrame(apples_rows)], ignore_index=True)

# %%
plt.figure(figsize=(10, 6))

metrics = ['Accuracy', 'Precision', 'Recall', 'F1']

for i, metric in enumerate(metrics):
    plt.subplot(2, 2, i + 1)
    sns.barplot(x='Classifier', y=metric, data=apples_results, palette='Blues_d')
    plt.title(metric)
    plt.xlabel('Classifier')
    plt.ylabel(metric)

plt.suptitle('Apple Quality Results')
plt.tight_layout()
plt.savefig('../classification_plots/apples/apple_results.png')
plt.show()
# Out:
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/2944711040.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Classifier', y=metric, data=apples_results, palette='Blues_d')
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/2944711040.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Classifier', y=metric, data=apples_results, palette='Blues_d')
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/2944711040.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ## Stroke

# %%
stroke_columns = ['Classifier', 'Accuracy', 'Precision', 'Recall', 'F1']
stroke_results = pd.DataFrame(columns=stroke_columns)
stroke_rows = []

# %%
y = stroke['stroke'].to_numpy()
stroke_x = stroke[['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi']]
X = stroke_x.to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### K-Nearest Neighbors

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'KNN',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

stroke_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/stroke/knn_cm.png')
plt.show()

# %% [markdown]
# #### Support Vector Machine

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'SVM',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

stroke_rows.append(metrics)
# Out:
# /Users/juliasteed/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/stroke/svm_cm.png')
plt.show()

# %% [markdown]
# #### Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'NB',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

stroke_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/stroke/naive_cm.png')
plt.show()

# %% [markdown]
# #### Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'RF',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

stroke_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/stroke/rf_cm.png')
plt.show()

# %% [markdown]
# #### Logistic Regression

# %%
logreg = LogisticRegression(random_state=42)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'LR',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

stroke_rows.append(metrics)
# Out:
# /Users/juliasteed/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/stroke/log_reg_cm.png')
plt.show()

# %% [markdown]
# #### Decision Tree

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'DT',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

stroke_rows.append(metrics)
# Out:
# /Users/juliasteed/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/stroke/d_tree_cm.png')
plt.show()

# %%
stroke_results = pd.concat([stroke_results, pd.DataFrame(stroke_rows)], ignore_index=True)
print(stroke_results)
# Out:
#   Classifier  Accuracy  Precision    Recall        F1
# 0        KNN  0.940723   0.250000  0.020833  0.038462
# 1        SVM  0.943094   0.000000  0.000000  0.000000
# 2         NB  0.873740   0.208955  0.437500  0.282828
# 3         RF  0.938945   0.181818  0.020833  0.037383
# 4         LR  0.943094   0.000000  0.000000  0.000000
# 5         DT  0.943094   0.000000  0.000000  0.000000
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/589830371.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stroke_results = pd.concat([stroke_results, pd.DataFrame(stroke_rows)], ignore_index=True)

# %%
plt.figure(figsize=(10, 6))

metrics = ['Accuracy', 'Precision', 'Recall', 'F1']

for i, metric in enumerate(metrics):
    plt.subplot(2, 2, i + 1)
    sns.barplot(x='Classifier', y=metric, data=stroke_results, palette='Blues_d')
    plt.title(metric)
    plt.xlabel('Classifier')
    plt.ylabel(metric)

plt.suptitle('Stroke Results')
plt.tight_layout()
plt.savefig('../classification_plots/stroke/stroke_results.png')
plt.show()
# Out:
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/302003420.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Classifier', y=metric, data=stroke_results, palette='Blues_d')
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/302003420.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Classifier', y=metric, data=stroke_results, palette='Blues_d')
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/302003420.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
accidents_columns = ['Classifier', 'Accuracy', 'Precision', 'Recall', 'F1']
accidents_results = pd.DataFrame(columns=accidents_columns)
accidents_rows = []

# %% [markdown]
# ## Accidents Survived

# %%
y = accidents['Survived'].to_numpy()
apples_x = accidents[['Age','Gender','Speed_of_Impact','Helmet_Used', 'Seatbelt_Used']]
X = apples_x.to_numpy()

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### K-Nearest Neighbors

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'KNN',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

accidents_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/accidents/knn_cm.png')
plt.show()

# %% [markdown]
# #### Support Vector Machine

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'SVM',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

accidents_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/accidents/svm_cm.png')
plt.show()

# %% [markdown]
# #### Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'NB',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

accidents_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/accidents/naive_cm.png')
plt.show()

# %% [markdown]
# #### Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'RF',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

accidents_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/accidents/rf_cm.png')
plt.show()

# %% [markdown]
# #### Logistic Regression

# %%
logreg = LogisticRegression(random_state=42)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'LR',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

accidents_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/accidents/log_reg_cm.png')
plt.show()

# %% [markdown]
# #### Decision Tree

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = {
    'Classifier': 'DT',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

accidents_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/accidents/d_tree_cm.png')
plt.show()

# %%
accidents_results = pd.concat([accidents_results, pd.DataFrame(accidents_rows)], ignore_index=True)
print(accidents_results)
# Out:
#   Classifier  Accuracy  Precision    Recall        F1
# 0        KNN  0.538462   0.500000  0.633333  0.558824
# 1        SVM  0.492308   0.473684  0.900000  0.620690
# 2         NB  0.492308   0.469388  0.766667  0.582278
# 3         RF  0.507692   0.476190  0.666667  0.555556
# 4         LR  0.492308   0.468085  0.733333  0.571429
# 5         DT  0.630769   0.583333  0.700000  0.636364
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/2262684928.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   accidents_results = pd.concat([accidents_results, pd.DataFrame(accidents_rows)], ignore_index=True)

# %%
plt.figure(figsize=(10, 6))

metrics = ['Accuracy', 'Precision', 'Recall', 'F1']

for i, metric in enumerate(metrics):
    plt.subplot(2, 2, i + 1)
    sns.barplot(x='Classifier', y=metric, data=accidents_results, palette='Blues_d')
    plt.title(metric)
    plt.xlabel('Classifier')
    plt.ylabel(metric)

plt.suptitle('Car Accident Results')
plt.tight_layout()
plt.savefig('../classification_plots/accidents/accident_results.png')
plt.show()
# Out:
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/2432229262.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Classifier', y=metric, data=accidents_results, palette='Blues_d')
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/2432229262.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Classifier', y=metric, data=accidents_results, palette='Blues_d')
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/2432229262.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ## Spotify Track Genre

# %%
label_encoder = LabelEncoder()
spotify['track_genre'] = label_encoder.fit_transform(spotify['track_genre'])  
spotify['explicit'] = spotify['explicit'].astype(int)

df = spotify.fillna(spotify.median())

# Genre
X = df.drop(columns=['track_genre'])
y = df['track_genre']
# Explicit
# X = df.drop(columns=['explicit'])
# y = df['explicit']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
spotify_columns = ['Classifier', 'Accuracy', 'Precision', 'Recall', 'F1']
spotify_results = pd.DataFrame(columns=spotify_columns)

# %% [markdown]
# #### K-Nearest Neighbors

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

metrics = {
    'Classifier': 'KNN',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}
spotify_rows = []
spotify_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/spotify/knn_cm_genre.png')
plt.show()

# %% [markdown]
# #### Support Vector Machine

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

metrics = {
    'Classifier': 'SVM',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

spotify_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/spotify/svm_cm_genre.png')
plt.show()

# %% [markdown]
# #### Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

metrics = {
    'Classifier': 'NB',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

spotify_rows.append(metrics)
# Out:
# /Users/juliasteed/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/spotify/naive_cm_genre.png')
plt.show()

# %% [markdown]
# #### Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

metrics = {
    'Classifier': 'RF',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

spotify_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/spotify/rf_cm_genre.png')
plt.show()

# %% [markdown]
# #### Logistic Regression

# %%
logreg = LogisticRegression(random_state=42)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

metrics = {
    'Classifier': 'LR',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

spotify_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/spotify/log_reg_cm_genre.png')
plt.show()

# %% [markdown]
# #### Decision Tree

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

metrics = {
    'Classifier': 'DT',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1
}

spotify_rows.append(metrics)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.savefig('../classification_plots/spotify/d_tree_cm_genre.png')
plt.show()

# %%
spotify_results = pd.concat([spotify_results, pd.DataFrame(spotify_rows)], ignore_index=True)
print(spotify_results)
# Out:
#   Classifier  Accuracy  Precision    Recall        F1
# 0        KNN  0.202222   0.216251  0.202222  0.199746
# 1        SVM  0.274327   0.258621  0.274327  0.251531
# 2         NB  0.110205   0.132619  0.110205  0.078566
# 3         RF  0.328684   0.319167  0.328684  0.319894
# 4         LR  0.203041   0.168457  0.203041  0.172605
# 5         DT  0.203041   0.168457  0.203041  0.172605
# 6         DT  0.214825   0.220768  0.214825  0.216749
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/787422691.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   spotify_results = pd.concat([spotify_results, pd.DataFrame(spotify_rows)], ignore_index=True)

# %%
plt.figure(figsize=(10, 6))

metrics = ['Accuracy', 'Precision', 'Recall', 'F1']

for i, metric in enumerate(metrics):
    plt.subplot(2, 2, i + 1)
    sns.barplot(x='Classifier', y=metric, data=spotify_results, palette='Blues_d')
    plt.title(metric)
    plt.xlabel('Classifier')
    plt.ylabel(metric)

plt.suptitle('Spotify Results')
plt.tight_layout()
plt.savefig('../classification_plots/spotify/spotify_results_genre.png')
plt.show()
# Out:
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/1786371484.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Classifier', y=metric, data=spotify_results, palette='Blues_d')
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/1786371484.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Classifier', y=metric, data=spotify_results, palette='Blues_d')
# /var/folders/k6/sf8fkfl90gjc74kqjcpgm1jh0000gn/T/ipykernel_93928/1786371484.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
